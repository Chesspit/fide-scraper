# %% [markdown]
# # 17 — Stärke-Bucket-Auswertung: Top-20-Frauen im 2400+-Fenster
#
# **Top-20-Pendant zu Notebook 16** (dort Top-40) — identischer Aufbau, einziger fachlicher Unterschied: die Jahresend-Rangschwelle ist `rnk <= 20` statt `rnk <= 40`. Top-20-Frauen nach Jahresend-Elo (`published_rating`, Dezember 2016–2025), gefiltert auf aktuell **aktive** Spielerinnen. Pro Spielerin wird zusätzlich ihr **Schwellenjahr** bestimmt — das erste Jahr, in dem ihre Dezember-Elo ≥ 2400 lag — und nur Partien **ab diesem Jahr bis 2025** (permanent, auch bei späteren Rückgängen unter 2400) fließen in die Analyse ein.
#
# Jede Partie wird nach **Gegnerstärke zum Zeitpunkt der Partie** in drei Gruppen eingeteilt (`diff = opponent_rating − own_rating`, `own_rating` = `std_rating` aus `rating_history` zur jeweiligen Periode — bewusst ein anderes Rating-Konzept als die `published_rating`-Jahresendwerte, die die Kohorte/Schwelle definieren):
#
# - **schwächer**: `diff < -50`
# - **gleich stark**: `-50 <= diff <= 50` (beide Grenzen inklusive)
# - **stärker**: `diff > 50`
#
# Dazu ein vierter Bucket **Gesamt**, der die drei Stärke-Gruppen zu einer Zeile zusammenfasst (alle Partien, unabhängig vom Stärkeverhältnis).
#
# Jede Gruppe wird zusätzlich nach Gegner-Geschlecht aufgeschlüsselt (Gesamt/vs. Frauen/vs. Männer). Kennzahlen: Sieg/Remis/Niederlage, Punktequote, Ø-Gegner-Elo, Ø-Elo-Änderung (`rating_change_weighted`), Anzahl Partien.
#
# **Datenarchitektur:** wie Notebook 16 — ein einziger Partien-Faktentensor (`games`) trägt alle nötigen Spalten (`name`, `year`, `strength_bucket`, `opponent_sex`); eine generische `summarize()`/`build_table()`-Kombination erzeugt daraus je nach übergebenen Gruppierungsspalten alle Tabellen unten, auch der `Gesamt`-Bucket entsteht per Rollup statt als Extra-Codepfad.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd()))
from _setup import load_query, apply_style

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

apply_style()
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ## Kohorte + Schwellenjahr laden
#
# Eine Query liefert für jede Spielerin, die je in einem Top-20-Jahresende stand, ihre komplette Jahresend-Historie 2016–2025 (Rang + Rating) — daraus werden in Pandas `year_added` (erstes Top-20-Jahr) und `threshold_year` (erstes Jahr mit `published_rating >= 2400`) abgeleitet und auf `active = TRUE` gefiltert.

# %%
sql_roster = '''
WITH female_years AS (
    SELECT rh.fide_id, p.name, p.active, rh.period, rh.published_rating,
           ROW_NUMBER() OVER (PARTITION BY rh.period ORDER BY rh.published_rating DESC) AS rnk
    FROM rating_history rh
    JOIN players p ON p.fide_id = rh.fide_id
    WHERE p.sex = 'F'
      AND rh.published_rating IS NOT NULL
      AND rh.period IN ('2016-12-01','2017-12-01','2018-12-01','2019-12-01','2020-12-01',
                        '2021-12-01','2022-12-01','2023-12-01','2024-12-01','2025-12-01')
),
top20_ids AS (
    SELECT DISTINCT fide_id FROM female_years WHERE rnk <= 20
)
SELECT fy.fide_id, fy.name, fy.active, fy.period, fy.published_rating, fy.rnk
FROM female_years fy
JOIN top20_ids t ON t.fide_id = fy.fide_id
'''
raw = load_query(sql_roster)
raw['year'] = pd.to_datetime(raw['period']).dt.year
raw_active = raw[raw['active']].copy()

year_added = raw_active[raw_active['rnk'] <= 20].groupby('fide_id')['year'].min().rename('year_added')
threshold_year = raw_active[raw_active['published_rating'] >= 2400].groupby('fide_id')['year'].min().rename('threshold_year')
names = raw_active.drop_duplicates('fide_id').set_index('fide_id')['name']

roster = pd.concat([names, year_added, threshold_year], axis=1).reset_index()
assert roster['threshold_year'].notna().all(), 'Spielerin ohne Schwellenjahr gefunden'
roster['year_added'] = roster['year_added'].astype(int)
roster['threshold_year'] = roster['threshold_year'].astype(int)
roster = roster.sort_values('name').reset_index(drop=True)

print(f'Kohorte: {len(roster)} Spielerinnen')
print('Schwellenjahr-Verteilung:')
print(roster['threshold_year'].value_counts().sort_index())
# Out:
# Kohorte: 27 Spielerinnen
# Schwellenjahr-Verteilung:
# threshold_year
# 2016    22
# 2018     2
# 2021     2
# 2023     1
# Name: count, dtype: int64

# %% [markdown]
# ## Partien-Fakten-Tabelle laden
#
# Pro Spielerin nur Partien ab ihrem individuellen Schwellenjahr (`VALUES`-Liste aus `roster`, ein Fenster pro Spielerin statt eines einzigen globalen Zeitraums). `own_rating` wie in Notebook 13–16 per `LEFT JOIN rating_history` auf `std_rating` (Rating zum Partie-Zeitpunkt, nicht der Jahresend-Snapshot).

# %%
values_rows = ',\n    '.join(
    f"({int(fid)}, DATE '{int(ty)}-01-01')"
    for fid, ty in zip(roster['fide_id'], roster['threshold_year'])
)
sql_games = f'''
WITH windows(fide_id, start_date) AS (
    VALUES
    {values_rows}
)
SELECT gr.fide_id, gr.period, gr.opponent_rating, gr.opponent_sex,
       gr.result, gr.rating_change_weighted, rh.std_rating AS own_rating
FROM game_results gr
JOIN windows w             ON w.fide_id = gr.fide_id
LEFT JOIN rating_history rh ON rh.fide_id = gr.fide_id AND rh.period = gr.period
WHERE gr.period >= w.start_date AND gr.period <= '2025-12-31'
'''
games_raw = load_query(sql_games)
games_raw = games_raw.merge(roster[['fide_id', 'name']], on='fide_id', how='left')

games_raw['result'] = games_raw['result'].astype(float)
games_raw['rating_change_weighted'] = games_raw['rating_change_weighted'].astype(float)
games_raw['own_rating'] = pd.to_numeric(games_raw['own_rating'], errors='coerce')
games_raw['opponent_rating'] = pd.to_numeric(games_raw['opponent_rating'], errors='coerce')
games_raw['year'] = pd.to_datetime(games_raw['period']).dt.year

n_raw = len(games_raw)
games = games_raw.dropna(subset=['own_rating', 'opponent_rating']).copy()
print(f'{n_raw:,} Partien geladen, {n_raw - len(games):,} ohne own_rating/opponent_rating verworfen '
      f'({(n_raw - len(games)) / n_raw:.1%}) -> {len(games):,} Partien in der Analyse')
print(f'Eindeutige Spielerinnen mit Partien: {games["fide_id"].nunique()}')

games['diff'] = games['opponent_rating'] - games['own_rating']

def strength_bucket(d):
    if pd.isna(d):
        return 'unknown'
    if d > 50:
        return 'stärker'
    if d < -50:
        return 'schwächer'
    return 'gleich'
games['strength_bucket'] = games['diff'].apply(strength_bucket)

BUCKET_ORDER = ['schwächer', 'gleich', 'stärker']
BUCKET_ORDER_FULL = BUCKET_ORDER + ['Gesamt']
SEX_GROUP_ORDER = ['Gesamt', 'F', 'M']
N_COLS = ['n_partien', 'siege', 'remis', 'niederlagen']
games['strength_bucket'].value_counts().reindex(BUCKET_ORDER)
# Out:
# 12,964 Partien geladen, 0 ohne own_rating/opponent_rating verworfen (0.0%) -> 12,964 Partien in der Analyse
# Eindeutige Spielerinnen mit Partien: 27
# strength_bucket
# schwächer    7478
# gleich       3262
# stärker      2224
# Name: count, dtype: int64

# %% [markdown]
# ## 1. Partien pro Jahr × Spielerin

# %%
year_pivot = games.groupby(['name', 'year']).size().unstack(fill_value=0)
for y in range(2016, 2026):
    if y not in year_pivot.columns:
        year_pivot[y] = 0
year_pivot = year_pivot[sorted(year_pivot.columns)]
year_pivot['Gesamt'] = year_pivot.sum(axis=1)
year_pivot = year_pivot.sort_values('Gesamt', ascending=False)
year_pivot
# Out:
# year                        2016  2017  2018  2019  2020  2021  2022  2023  \
# name
# Batsiashvili, Nino            96   100    76    87    58    64   108    80
# Paehtz, Elisabeth            118   100    88    89    42    65    45    65
# Goryachkina, Aleksandra      104    72    98    93    52    76    26    79
# Shuvalova, Polina              0     0    96    96    59    80    68    79
# Kosteniuk, Alexandra          82    63    86    79    42    50    24    63
# Girya, Olga                   73    91   107    79    25    82    60     6
# Kashlinskaya, Alina           75    91    94    70    13    60    54    25
# Gunina, Valentina             66    55    82    80    39    92    27    69
# Stefanova, Antoaneta          83    70    49    79    32    38    57    60
# Lei, Tingjie                 128   135    91    87    13    11     8    17
# Tan, Zhongyi                  83    81    49    81    15    32    22    67
# Dronavalli, Harika            83    80    46    91    31    14     7    65
# Ju, Wenjun                   109    78    64    62    36    11     6    42
# Dzagnidze, Nana               81    51    49    64    31    43    24    42
# Muzychuk, Anna                72    60    52    43    33    31    34    57
# Muzychuk, Mariya              78    26    90    45    31    34    43    49
# Khademalsharieh, Sarasadat   112    81    73    58     9    14     2    25
# Zhu, Jiner                     0     0    75   109     9    31    42    55
# Pogonina, Natalija            69    49    83    56    28    45    23    19
# Vaishali, Rameshbabu           0     0     0     0     0    60    97   104
# Lagno, Kateryna               12    44    27    65    20    34    19    37
# Divya Deshmukh                 0     0     0     0     0     0     0   119
# Assaubayeva, Bibisara          0     0     0     0     0    47    59    60
# Koneru, Humpy                 31     0    13    37    20     0    14    36
# Hou, Yifan                    84    69    27     5     2     0    11    15
# Sebag, Marie                   4    23    30    57    11    25    37    15
# Zhao, Xue                     96    36     7     0    11     0     0    21
#
# year                        2024  2025  Gesamt
# name
# Batsiashvili, Nino            69    71     809
# Paehtz, Elisabeth             51    48     711
# Goryachkina, Aleksandra       41    55     696
# Shuvalova, Polina            106    87     671
# Kosteniuk, Alexandra          39    63     591
# Girya, Olga                   11    50     584
# Kashlinskaya, Alina           28    55     565
# Gunina, Valentina             18    37     565
# Stefanova, Antoaneta          51    40     559
# Lei, Tingjie                  28    36     554
# Tan, Zhongyi                  41    79     550
# Dronavalli, Harika            54    64     535
# Ju, Wenjun                    51    35     494
# Dzagnidze, Nana               42    64     491
# Muzychuk, Anna                59    50     491
# Muzychuk, Mariya              31    51     478
# Khademalsharieh, Sarasadat    46    47     467
# Zhu, Jiner                    69    74     464
# Pogonina, Natalija            34    45     451
# Vaishali, Rameshbabu          84    69     414
# Lagno, Kateryna               34    37     329
# Divya Deshmukh               101    79     299
# Assaubayeva, Bibisara         79    50     295
# Koneru, Humpy                 42    49     242
# Hou, Yifan                     3    26     242
# Sebag, Marie                  15    16     233
# Zhao, Xue                      7     6     184

# %% [markdown]
# ## 2. Kennzahlen-Helfer
#
# `summarize()` liefert für eine beliebige Partien-Teilmenge Sieg/Remis/Niederlage, Punktequote, Ø-Gegner-Elo und Ø-Elo-Änderung. `with_bucket_rollup()` verdoppelt den DataFrame um eine zusätzliche `strength_bucket == 'Gesamt'`-Kopie (Summe über schwächer/gleich/stärker); `with_sex_rollup()` verdreifacht zusätzlich nach Gegner-Geschlecht (Gesamt/vs. F/vs. M als Spalte `sex_group`). Beide zusammen liefern in einem einzigen `groupby` sowohl die volle Stärke- als auch die Geschlechts-Aufschlüsselung inkl. Gesamtzeilen. `build_table()` gruppiert nach beliebigen Spalten — dieselbe Funktion erzeugt alle Tabellen unten, nur mit anderen Gruppierungsspalten.

# %%
def summarize(sub):
    n = len(sub)
    if n == 0:
        return pd.Series({
            'n_partien': 0, 'siege': 0, 'remis': 0, 'niederlagen': 0,
            'punktequote': np.nan, 'avg_opponent_rating': np.nan, 'mean_delta': np.nan,
        })
    return pd.Series({
        'n_partien': n,
        'siege': (sub['result'] == 1).sum(),
        'remis': (sub['result'] == 0.5).sum(),
        'niederlagen': (sub['result'] == 0).sum(),
        'punktequote': sub['result'].mean(),
        'avg_opponent_rating': sub['opponent_rating'].mean(),
        'mean_delta': sub['rating_change_weighted'].mean(),
    })

def with_sex_rollup(df_scope):
    return pd.concat([
        df_scope.assign(sex_group='Gesamt'),
        df_scope[df_scope.opponent_sex == 'F'].assign(sex_group='F'),
        df_scope[df_scope.opponent_sex == 'M'].assign(sex_group='M'),
    ], ignore_index=True)

def with_bucket_rollup(df_scope):
    return pd.concat([
        df_scope,
        df_scope.assign(strength_bucket='Gesamt'),
    ], ignore_index=True)

def build_table(df_scope, group_cols):
    return df_scope.groupby(group_cols).apply(summarize, include_groups=False).reset_index()

games_full = with_sex_rollup(with_bucket_rollup(games))
print(f'games_full: {len(games_full):,} Zeilen (Original × 4 Stärke-Buckets [inkl. Gesamt] × Gesamt/F/M-Rollup)')
# Out:
# games_full: 51,566 Zeilen (Original × 4 Stärke-Buckets [inkl. Gesamt] × Gesamt/F/M-Rollup)

# %% [markdown]
# ## 3. Gesamtzeitraum — pro Spielerin × Bucket × Geschlecht
#
# Vollständiges Raster (Spielerinnen × 4 Buckets [schwächer/gleich/stärker + **Gesamt** als Summe der drei] × 3 Geschlechts-Gruppen); Kombinationen ohne Partien erscheinen mit 0.

# %%
full_index_overall_player = pd.MultiIndex.from_product(
    [roster['name'], BUCKET_ORDER_FULL, SEX_GROUP_ORDER],
    names=['name', 'strength_bucket', 'sex_group'],
)
table_overall = (
    build_table(games_full, ['name', 'strength_bucket', 'sex_group'])
    .set_index(['name', 'strength_bucket', 'sex_group'])
    .reindex(full_index_overall_player)
)
table_overall[N_COLS] = table_overall[N_COLS].fillna(0).astype(int)
table_overall = table_overall.reset_index()
table_overall.round(3)
# Out:
#                            name strength_bucket sex_group  n_partien  siege  \
# 0         Assaubayeva, Bibisara       schwächer    Gesamt        116     57
# 1         Assaubayeva, Bibisara       schwächer         F         55     23
# 2         Assaubayeva, Bibisara       schwächer         M         60     33
# 3         Assaubayeva, Bibisara          gleich    Gesamt         73     20
# 4         Assaubayeva, Bibisara          gleich         F         65     17
# 5         Assaubayeva, Bibisara          gleich         M          8      3
# 6         Assaubayeva, Bibisara         stärker    Gesamt        106     15
# 7         Assaubayeva, Bibisara         stärker         F         36      7
# 8         Assaubayeva, Bibisara         stärker         M         69      8
# 9         Assaubayeva, Bibisara          Gesamt    Gesamt        295     92
# 10        Assaubayeva, Bibisara          Gesamt         F        156     47
# 11        Assaubayeva, Bibisara          Gesamt         M        137     44
# 12           Batsiashvili, Nino       schwächer    Gesamt        520    288
# 13           Batsiashvili, Nino       schwächer         F        412    222
# 14           Batsiashvili, Nino       schwächer         M        103     66
# 15           Batsiashvili, Nino          gleich    Gesamt        169     50
# 16           Batsiashvili, Nino          gleich         F        135     39
# 17           Batsiashvili, Nino          gleich         M         33     10
# 18           Batsiashvili, Nino         stärker    Gesamt        120     20
# 19           Batsiashvili, Nino         stärker         F         33      7
# 20           Batsiashvili, Nino         stärker         M         87     13
# 21           Batsiashvili, Nino          Gesamt    Gesamt        809    358
# 22           Batsiashvili, Nino          Gesamt         F        580    268
# 23           Batsiashvili, Nino          Gesamt         M        223     89
# 24               Divya Deshmukh       schwächer    Gesamt        128     95
# 25               Divya Deshmukh       schwächer         F         89     65
# 26               Divya Deshmukh       schwächer         M         38     29
# 27               Divya Deshmukh          gleich    Gesamt         60     16
# 28               Divya Deshmukh          gleich         F         51     14
# 29               Divya Deshmukh          gleich         M          9      2
# 30               Divya Deshmukh         stärker    Gesamt        111     15
# 31               Divya Deshmukh         stärker         F         17      3
# 32               Divya Deshmukh         stärker         M         94     12
# 33               Divya Deshmukh          Gesamt    Gesamt        299    126
# 34               Divya Deshmukh          Gesamt         F        157     82
# 35               Divya Deshmukh          Gesamt         M        141     43
# 36           Dronavalli, Harika       schwächer    Gesamt        235     91
# 37           Dronavalli, Harika       schwächer         F        185     57
# 38           Dronavalli, Harika       schwächer         M         49     33
# 39           Dronavalli, Harika          gleich    Gesamt        165     32
# 40           Dronavalli, Harika          gleich         F        153     31
# 41           Dronavalli, Harika          gleich         M         12      1
# 42           Dronavalli, Harika         stärker    Gesamt        135      7
# 43           Dronavalli, Harika         stärker         F         30      2
# 44           Dronavalli, Harika         stärker         M        103      5
# 45           Dronavalli, Harika          Gesamt    Gesamt        535    130
# 46           Dronavalli, Harika          Gesamt         F        368     90
# 47           Dronavalli, Harika          Gesamt         M        164     39
# 48              Dzagnidze, Nana       schwächer    Gesamt        281    143
# 49              Dzagnidze, Nana       schwächer         F        264    138
# 50              Dzagnidze, Nana       schwächer         M         16      5
# 51              Dzagnidze, Nana          gleich    Gesamt        183     44
# 52              Dzagnidze, Nana          gleich         F        180     44
# 53              Dzagnidze, Nana          gleich         M          3      0
# 54              Dzagnidze, Nana         stärker    Gesamt         27      3
# 55              Dzagnidze, Nana         stärker         F         23      3
# 56              Dzagnidze, Nana         stärker         M          4      0
# 57              Dzagnidze, Nana          Gesamt    Gesamt        491    190
# 58              Dzagnidze, Nana          Gesamt         F        467    185
# 59              Dzagnidze, Nana          Gesamt         M         23      5
# 60                  Girya, Olga       schwächer    Gesamt        343    173
# 61                  Girya, Olga       schwächer         F        286    141
# 62                  Girya, Olga       schwächer         M         25     13
# 63                  Girya, Olga          gleich    Gesamt        128     38
# 64                  Girya, Olga          gleich         F        114     33
# 65                  Girya, Olga          gleich         M         10      5
# 66                  Girya, Olga         stärker    Gesamt        113     13
# 67                  Girya, Olga         stärker         F         56      7
# 68                  Girya, Olga         stärker         M         56      6
# 69                  Girya, Olga          Gesamt    Gesamt        584    224
# 70                  Girya, Olga          Gesamt         F        456    181
# 71                  Girya, Olga          Gesamt         M         91     24
# 72      Goryachkina, Aleksandra       schwächer    Gesamt        406    170
# 73      Goryachkina, Aleksandra       schwächer         F        311    131
# 74      Goryachkina, Aleksandra       schwächer         M         92     38
# 75      Goryachkina, Aleksandra          gleich    Gesamt        149     28
# 76      Goryachkina, Aleksandra          gleich         F        104     17
# 77      Goryachkina, Aleksandra          gleich         M         43      9
# 78      Goryachkina, Aleksandra         stärker    Gesamt        141     16
# 79      Goryachkina, Aleksandra         stärker         F          6      1
# 80      Goryachkina, Aleksandra         stärker         M        135     15
# 81      Goryachkina, Aleksandra          Gesamt    Gesamt        696    214
# 82      Goryachkina, Aleksandra          Gesamt         F        421    149
# 83      Goryachkina, Aleksandra          Gesamt         M        270     62
# 84            Gunina, Valentina       schwächer    Gesamt        350    209
# 85            Gunina, Valentina       schwächer         F        284    162
# 86            Gunina, Valentina       schwächer         M         40     31
# 87            Gunina, Valentina          gleich    Gesamt        147     50
# 88            Gunina, Valentina          gleich         F        142     50
# 89            Gunina, Valentina          gleich         M          3      0
# 90            Gunina, Valentina         stärker    Gesamt         68     13
# 91            Gunina, Valentina         stärker         F         47     12
# 92            Gunina, Valentina         stärker         M         21      1
# 93            Gunina, Valentina          Gesamt    Gesamt        565    272
# 94            Gunina, Valentina          Gesamt         F        473    224
# 95            Gunina, Valentina          Gesamt         M         64     32
# 96                   Hou, Yifan       schwächer    Gesamt        124     74
# 97                   Hou, Yifan       schwächer         F         80     48
# 98                   Hou, Yifan       schwächer         M         42     25
# 99                   Hou, Yifan          gleich    Gesamt         39      6
# 100                  Hou, Yifan          gleich         F          0      0
# 101                  Hou, Yifan          gleich         M         39      6
# 102                  Hou, Yifan         stärker    Gesamt         79      6
# 103                  Hou, Yifan         stärker         F          0      0
# 104                  Hou, Yifan         stärker         M         79      6
# 105                  Hou, Yifan          Gesamt    Gesamt        242     86
# 106                  Hou, Yifan          Gesamt         F         80     48
# 107                  Hou, Yifan          Gesamt         M        160     37
# 108                  Ju, Wenjun       schwächer    Gesamt        308    154
# 109                  Ju, Wenjun       schwächer         F        258    125
# 110                  Ju, Wenjun       schwächer         M         49     28
# 111                  Ju, Wenjun          gleich    Gesamt        114     34
# 112                  Ju, Wenjun          gleich         F         87     25
# 113                  Ju, Wenjun          gleich         M         26      9
# 114                  Ju, Wenjun         stärker    Gesamt         72     11
# 115                  Ju, Wenjun         stärker         F          1      1
# 116                  Ju, Wenjun         stärker         M         71     10
# 117                  Ju, Wenjun          Gesamt    Gesamt        494    199
# 118                  Ju, Wenjun          Gesamt         F        346    151
# 119                  Ju, Wenjun          Gesamt         M        146     47
# 120         Kashlinskaya, Alina       schwächer    Gesamt        319    176
# 121         Kashlinskaya, Alina       schwächer         F        258    137
# 122         Kashlinskaya, Alina       schwächer         M         56     35
# 123         Kashlinskaya, Alina          gleich    Gesamt        178     50
# 124         Kashlinskaya, Alina          gleich         F        163     46
# 125         Kashlinskaya, Alina          gleich         M         14      3
# 126         Kashlinskaya, Alina         stärker    Gesamt         68     13
# 127         Kashlinskaya, Alina         stärker         F         36      6
# 128         Kashlinskaya, Alina         stärker         M         32      7
# 129         Kashlinskaya, Alina          Gesamt    Gesamt        565    239
# 130         Kashlinskaya, Alina          Gesamt         F        457    189
# 131         Kashlinskaya, Alina          Gesamt         M        102     45
# 132  Khademalsharieh, Sarasadat       schwächer    Gesamt        272    155
# 133  Khademalsharieh, Sarasadat       schwächer         F        201    115
# 134  Khademalsharieh, Sarasadat       schwächer         M         71     40
# 135  Khademalsharieh, Sarasadat          gleich    Gesamt         65     14
# 136  Khademalsharieh, Sarasadat          gleich         F         53     10
# 137  Khademalsharieh, Sarasadat          gleich         M         12      4
# 138  Khademalsharieh, Sarasadat         stärker    Gesamt        130     25
# 139  Khademalsharieh, Sarasadat         stärker         F         53     15
# 140  Khademalsharieh, Sarasadat         stärker         M         76     10
# 141  Khademalsharieh, Sarasadat          Gesamt    Gesamt        467    194
# 142  Khademalsharieh, Sarasadat          Gesamt         F        307    140
# 143  Khademalsharieh, Sarasadat          Gesamt         M        159     54
# 144               Koneru, Humpy       schwächer    Gesamt        164     71
# 145               Koneru, Humpy       schwächer         F        142     61
# 146               Koneru, Humpy       schwächer         M         22     10
# 147               Koneru, Humpy          gleich    Gesamt         72     13
# 148               Koneru, Humpy          gleich         F         72     13
# 149               Koneru, Humpy          gleich         M          0      0
# 150               Koneru, Humpy         stärker    Gesamt          6      0
# 151               Koneru, Humpy         stärker         F          1      0
# 152               Koneru, Humpy         stärker         M          5      0
# 153               Koneru, Humpy          Gesamt    Gesamt        242     84
# 154               Koneru, Humpy          Gesamt         F        215     74
# 155               Koneru, Humpy          Gesamt         M         27     10
# 156        Kosteniuk, Alexandra       schwächer    Gesamt        357    171
# 157        Kosteniuk, Alexandra       schwächer         F        300    140
# 158        Kosteniuk, Alexandra       schwächer         M         56     30
# 159        Kosteniuk, Alexandra          gleich    Gesamt        178     57
# 160        Kosteniuk, Alexandra          gleich         F        159     52
# 161        Kosteniuk, Alexandra          gleich         M         19      5
# 162        Kosteniuk, Alexandra         stärker    Gesamt         56      8
# 163        Kosteniuk, Alexandra         stärker         F         34      6
# 164        Kosteniuk, Alexandra         stärker         M         22      2
# 165        Kosteniuk, Alexandra          Gesamt    Gesamt        591    236
# 166        Kosteniuk, Alexandra          Gesamt         F        493    198
# 167        Kosteniuk, Alexandra          Gesamt         M         97     37
# 168             Lagno, Kateryna       schwächer    Gesamt        208     96
# 169             Lagno, Kateryna       schwächer         F        188     84
# 170             Lagno, Kateryna       schwächer         M         20     12
# 171             Lagno, Kateryna          gleich    Gesamt        101     14
# 172             Lagno, Kateryna          gleich         F         97     14
# 173             Lagno, Kateryna          gleich         M          4      0
# 174             Lagno, Kateryna         stärker    Gesamt         20      1
# 175             Lagno, Kateryna         stärker         F          0      0
# 176             Lagno, Kateryna         stärker         M         20      1
# 177             Lagno, Kateryna          Gesamt    Gesamt        329    111
# 178             Lagno, Kateryna          Gesamt         F        285     98
# 179             Lagno, Kateryna          Gesamt         M         44     13
# 180                Lei, Tingjie       schwächer    Gesamt        334    203
# 181                Lei, Tingjie       schwächer         F        220    127
# 182                Lei, Tingjie       schwächer         M        111     74
# 183                Lei, Tingjie          gleich    Gesamt        125     35
# 184                Lei, Tingjie          gleich         F        101     27
# 185                Lei, Tingjie          gleich         M         24      8
# 186                Lei, Tingjie         stärker    Gesamt         95     15
# 187                Lei, Tingjie         stärker         F          9      2
# 188                Lei, Tingjie         stärker         M         86     13
# 189                Lei, Tingjie          Gesamt    Gesamt        554    253
# 190                Lei, Tingjie          Gesamt         F        330    156
# 191                Lei, Tingjie          Gesamt         M        221     95
# 192              Muzychuk, Anna       schwächer    Gesamt        305    132
# 193              Muzychuk, Anna       schwächer         F        266    116
# 194              Muzychuk, Anna       schwächer         M         36     15
# 195              Muzychuk, Anna          gleich    Gesamt        158     27
# 196              Muzychuk, Anna          gleich         F        148     24
# 197              Muzychuk, Anna          gleich         M         10      3
# 198              Muzychuk, Anna         stärker    Gesamt         28      3
# 199              Muzychuk, Anna         stärker         F         10      1
# 200              Muzychuk, Anna         stärker         M         18      2
# 201              Muzychuk, Anna          Gesamt    Gesamt        491    162
# 202              Muzychuk, Anna          Gesamt         F        424    141
# 203              Muzychuk, Anna          Gesamt         M         64     20
# 204            Muzychuk, Mariya       schwächer    Gesamt        290    143
# 205            Muzychuk, Mariya       schwächer         F        259    124
# 206            Muzychuk, Mariya       schwächer         M         30     19
# 207            Muzychuk, Mariya          gleich    Gesamt        146     19
# 208            Muzychuk, Mariya          gleich         F        128     17
# 209            Muzychuk, Mariya          gleich         M         18      2
# 210            Muzychuk, Mariya         stärker    Gesamt         42      2
# 211            Muzychuk, Mariya         stärker         F         13      1
# 212            Muzychuk, Mariya         stärker         M         29      1
# 213            Muzychuk, Mariya          Gesamt    Gesamt        478    164
# 214            Muzychuk, Mariya          Gesamt         F        400    142
# 215            Muzychuk, Mariya          Gesamt         M         77     22
# 216           Paehtz, Elisabeth       schwächer    Gesamt        390    217
# 217           Paehtz, Elisabeth       schwächer         F        318    171
# 218           Paehtz, Elisabeth       schwächer         M         67     43
# 219           Paehtz, Elisabeth          gleich    Gesamt        184     31
# 220           Paehtz, Elisabeth          gleich         F        156     24
# 221           Paehtz, Elisabeth          gleich         M         27      6
# 222           Paehtz, Elisabeth         stärker    Gesamt        137     10
# 223           Paehtz, Elisabeth         stärker         F         60      4
# 224           Paehtz, Elisabeth         stärker         M         77      6
# 225           Paehtz, Elisabeth          Gesamt    Gesamt        711    258
# 226           Paehtz, Elisabeth          Gesamt         F        534    199
# 227           Paehtz, Elisabeth          Gesamt         M        171     55
# 228          Pogonina, Natalija       schwächer    Gesamt        288    134
# 229          Pogonina, Natalija       schwächer         F        214     95
# 230          Pogonina, Natalija       schwächer         M         46     22
# 231          Pogonina, Natalija          gleich    Gesamt        101     25
# 232          Pogonina, Natalija          gleich         F         90     22
# 233          Pogonina, Natalija          gleich         M         10      2
# 234          Pogonina, Natalija         stärker    Gesamt         62     11
# 235          Pogonina, Natalija         stärker         F         32      9
# 236          Pogonina, Natalija         stärker         M         30      2
# 237          Pogonina, Natalija          Gesamt    Gesamt        451    170
# 238          Pogonina, Natalija          Gesamt         F        336    126
# 239          Pogonina, Natalija          Gesamt         M         86     26
# 240                Sebag, Marie       schwächer    Gesamt        119     61
# 241                Sebag, Marie       schwächer         F        100     52
# 242                Sebag, Marie       schwächer         M         19      9
# 243                Sebag, Marie          gleich    Gesamt         68     11
# 244                Sebag, Marie          gleich         F         43      8
# 245                Sebag, Marie          gleich         M         25      3
# 246                Sebag, Marie         stärker    Gesamt         46      2
# 247                Sebag, Marie         stärker         F         22      0
# 248                Sebag, Marie         stärker         M         24      2
# 249                Sebag, Marie          Gesamt    Gesamt        233     74
# 250                Sebag, Marie          Gesamt         F        165     60
# 251                Sebag, Marie          Gesamt         M         68     14
# 252           Shuvalova, Polina       schwächer    Gesamt        430    246
# 253           Shuvalova, Polina       schwächer         F        300    173
# 254           Shuvalova, Polina       schwächer         M        128     71
# 255           Shuvalova, Polina          gleich    Gesamt        122     38
# 256           Shuvalova, Polina          gleich         F         92     32
# 257           Shuvalova, Polina          gleich         M         30      6
# 258           Shuvalova, Polina         stärker    Gesamt        119     22
# 259           Shuvalova, Polina         stärker         F         39      8
# 260           Shuvalova, Polina         stärker         M         79     14
# 261           Shuvalova, Polina          Gesamt    Gesamt        671    306
# 262           Shuvalova, Polina          Gesamt         F        431    213
# 263           Shuvalova, Polina          Gesamt         M        237     91
# 264        Stefanova, Antoaneta       schwächer    Gesamt        342    180
# 265        Stefanova, Antoaneta       schwächer         F        229    109
# 266        Stefanova, Antoaneta       schwächer         M        111     69
# 267        Stefanova, Antoaneta          gleich    Gesamt        122     26
# 268        Stefanova, Antoaneta          gleich         F        105     19
# 269        Stefanova, Antoaneta          gleich         M         17      7
# 270        Stefanova, Antoaneta         stärker    Gesamt         95     14
# 271        Stefanova, Antoaneta         stärker         F         42      7
# 272        Stefanova, Antoaneta         stärker         M         53      7
# 273        Stefanova, Antoaneta          Gesamt    Gesamt        559    220
# 274        Stefanova, Antoaneta          Gesamt         F        376    135
# 275        Stefanova, Antoaneta          Gesamt         M        181     83
# 276                Tan, Zhongyi       schwächer    Gesamt        324    181
# 277                Tan, Zhongyi       schwächer         F        282    158
# 278                Tan, Zhongyi       schwächer         M         42     23
# 279                Tan, Zhongyi          gleich    Gesamt        173     38
# 280                Tan, Zhongyi          gleich         F        168     35
# 281                Tan, Zhongyi          gleich         M          5      3
# 282                Tan, Zhongyi         stärker    Gesamt         53      9
# 283                Tan, Zhongyi         stärker         F         21      3
# 284                Tan, Zhongyi         stärker         M         32      6
# 285                Tan, Zhongyi          Gesamt    Gesamt        550    228
# 286                Tan, Zhongyi          Gesamt         F        471    196
# 287                Tan, Zhongyi          Gesamt         M         79     32
# 288        Vaishali, Rameshbabu       schwächer    Gesamt        168    104
# 289        Vaishali, Rameshbabu       schwächer         F         91     52
# 290        Vaishali, Rameshbabu       schwächer         M         77     52
# 291        Vaishali, Rameshbabu          gleich    Gesamt         87     25
# 292        Vaishali, Rameshbabu          gleich         F         67     18
# 293        Vaishali, Rameshbabu          gleich         M         20      7
# 294        Vaishali, Rameshbabu         stärker    Gesamt        159     24
# 295        Vaishali, Rameshbabu         stärker         F         54      6
# 296        Vaishali, Rameshbabu         stärker         M        105     18
# 297        Vaishali, Rameshbabu          Gesamt    Gesamt        414    153
# 298        Vaishali, Rameshbabu          Gesamt         F        212     76
# 299        Vaishali, Rameshbabu          Gesamt         M        202     77
# 300                   Zhao, Xue       schwächer    Gesamt        117     61
# 301                   Zhao, Xue       schwächer         F        102     49
# 302                   Zhao, Xue       schwächer         M         15     12
# 303                   Zhao, Xue          gleich    Gesamt         46     19
# 304                   Zhao, Xue          gleich         F         46     19
# 305                   Zhao, Xue          gleich         M          0      0
# 306                   Zhao, Xue         stärker    Gesamt         21      1
# 307                   Zhao, Xue         stärker         F         19      1
# 308                   Zhao, Xue         stärker         M          2      0
# 309                   Zhao, Xue          Gesamt    Gesamt        184     81
# 310                   Zhao, Xue          Gesamt         F        167     69
# 311                   Zhao, Xue          Gesamt         M         17     12
# 312                  Zhu, Jiner       schwächer    Gesamt        240    151
# 313                  Zhu, Jiner       schwächer         F        164    105
# 314                  Zhu, Jiner       schwächer         M         73     44
# 315                  Zhu, Jiner          gleich    Gesamt        109     38
# 316                  Zhu, Jiner          gleich         F         87     30
# 317                  Zhu, Jiner          gleich         M         22      8
# 318                  Zhu, Jiner         stärker    Gesamt        115     22
# 319                  Zhu, Jiner         stärker         F         42     10
# 320                  Zhu, Jiner         stärker         M         73     12
# 321                  Zhu, Jiner          Gesamt    Gesamt        464    211
# 322                  Zhu, Jiner          Gesamt         F        293    145
# 323                  Zhu, Jiner          Gesamt         M        168     64
#
#      remis  niederlagen  punktequote  avg_opponent_rating  mean_delta
# 0       51            8        0.711             2286.569      -0.032
# 1       29            3        0.682             2318.436      -0.098
# 2       22            5        0.733             2262.133       0.015
# 3       39           14        0.541             2475.014       0.495
# 4       36           12        0.538             2478.415       0.466
# 5        3            2        0.562             2447.375       0.725
# 6       58           33        0.415             2570.906       0.836
# 7       21            8        0.486             2529.556       1.194
# 8       37           24        0.384             2593.580       0.710
# 9      148           55        0.563             2435.369       0.410
# 10      86           23        0.577             2433.814       0.435
# 11      62           31        0.547             2439.883       0.407
# 12     161           71        0.709             2280.348      -0.225
# 13     131           59        0.698             2282.447      -0.312
# 14      27           10        0.772             2270.505       0.308
# 15      80           39        0.533             2463.231       0.276
# 16      65           31        0.530             2465.000       0.250
# 17      15            8        0.530             2458.455       0.258
# 18      44           56        0.350             2602.975       0.264
# 19      16           10        0.455             2561.061       0.730
# 20      28           46        0.310             2618.874       0.087
# 21     285          166        0.619             2366.408      -0.048
# 22     212          100        0.645             2340.790      -0.122
# 23      70           64        0.556             2434.229       0.214
# 24      26            7        0.844             2193.023       0.832
# 25      20            4        0.843             2172.831       0.633
# 26       6            3        0.842             2241.684       1.282
# 27      35            9        0.558             2442.350       0.562
# 28      31            6        0.578             2439.510       0.769
# 29       4            3        0.444             2458.444      -0.611
# 30      40           56        0.315             2576.342       0.091
# 31       7            7        0.382             2523.412       0.041
# 32      33           49        0.303             2585.915       0.100
# 33     101           72        0.590             2385.358       0.503
# 34      58           17        0.707             2297.420       0.613
# 35      43           55        0.457             2485.007       0.373
# 36     126           18        0.655             2339.196      -0.544
# 37     110           18        0.605             2354.919      -0.878
# 38      16            0        0.837             2278.143       0.631
# 39     108           25        0.521             2502.273       0.195
# 40     103           19        0.539             2500.392       0.352
# 41       5            6        0.292             2526.250      -1.817
# 42      87           41        0.374             2624.859       0.384
# 43      24            4        0.467             2571.333       0.587
# 44      62           36        0.350             2641.553       0.358
# 45     321           84        0.543             2461.574      -0.082
# 46     237           41        0.567             2433.043      -0.247
# 47      83           42        0.491             2524.537       0.280
# 48      98           40        0.683             2353.203      -0.231
# 49      91           35        0.695             2351.042      -0.119
# 50       6            5        0.500             2384.375      -1.969
# 51      96           43        0.503             2507.863      -0.081
# 52      95           41        0.508             2507.372      -0.030
# 53       1            2        0.167             2537.333      -3.133
# 54      12           12        0.333             2601.074      -0.522
# 55      11            9        0.370             2578.087      -0.430
# 56       1            3        0.125             2733.250      -1.050
# 57     206           95        0.597             2424.477      -0.191
# 58     197           85        0.607             2422.480      -0.100
# 59       8           10        0.391             2465.000      -1.961
# 60     130           40        0.694             2260.612      -0.374
# 61     112           33        0.689             2263.692      -0.406
# 62       8            4        0.680             2243.120      -0.572
# 63      61           29        0.535             2439.461       0.300
# 64      56           25        0.535             2442.500       0.314
# 65       2            3        0.600             2425.800       0.940
# 66      59           41        0.376             2551.664       0.246
# 67      34           15        0.429             2523.036       0.521
# 68      24           26        0.321             2579.946      -0.059
# 69     250          110        0.598             2356.128      -0.106
# 70     202           73        0.618             2340.243      -0.112
# 71      34           33        0.451             2470.473      -0.090
# 72     208           28        0.675             2387.293      -0.170
# 73     159           21        0.677             2392.688      -0.117
# 74      47            7        0.668             2370.435      -0.353
# 75      98           23        0.517             2532.591       0.117
# 76      71           16        0.505             2522.625      -0.075
# 77      27            7        0.523             2561.977       0.377
# 78      82           43        0.404             2636.298       0.623
# 79       3            2        0.417             2563.833       0.250
# 80      79           41        0.404             2639.519       0.640
# 81     388           94        0.586             2468.843       0.052
# 82     233           39        0.631             2427.226      -0.101
# 83     153           55        0.513             2535.481       0.260
# 84      76           65        0.706             2306.054      -0.100
# 85      64           58        0.683             2306.739      -0.303
# 86       6            3        0.850             2292.700       1.095
# 87      40           57        0.476             2478.565      -0.252
# 88      39           53        0.489             2480.289      -0.108
# 89       1            2        0.167             2452.000      -3.467
# 90      16           39        0.309             2573.456      -0.518
# 91      12           23        0.383             2540.170      -0.085
# 92       4           16        0.143             2647.952      -1.486
# 93     132          161        0.598             2383.120      -0.190
# 94     115          134        0.595             2382.036      -0.223
# 95      11           21        0.586             2416.734       0.034
# 96      36           14        0.742             2416.105      -0.305
# 97      26            6        0.762             2403.112      -0.146
# 98      10            7        0.714             2444.929      -0.486
# 99      24            9        0.462             2666.949      -0.303
# 100      0            0          NaN                  NaN         NaN
# 101     24            9        0.462             2666.949      -0.303
# 102     41           32        0.335             2762.177      -0.266
# 103      0            0          NaN                  NaN         NaN
# 104     41           32        0.335             2762.177      -0.266
# 105    101           55        0.564             2569.504      -0.292
# 106     26            6        0.762             2403.112      -0.146
# 107     75           48        0.466             2655.688      -0.332
# 108    136           18        0.721             2368.442      -0.237
# 109    118           15        0.713             2364.593      -0.345
# 110     18            3        0.755             2393.000       0.308
# 111     61           19        0.566             2555.096       0.446
# 112     49           13        0.569             2549.218       0.387
# 113     11            6        0.558             2572.846       0.638
# 114     35           26        0.396             2683.847       0.606
# 115      0            0        1.000             2651.000       5.900
# 116     35           26        0.387             2684.310       0.531
# 117    232           63        0.638             2457.486       0.043
# 118    167           28        0.678             2411.844      -0.143
# 119     64           35        0.541             2566.692       0.475
# 120    104           39        0.715             2291.182      -0.020
# 121     87           34        0.700             2304.171      -0.059
# 122     17            4        0.777             2238.446       0.139
# 123     81           47        0.508             2467.640       0.031
# 124     77           40        0.518             2467.724       0.116
# 125      4            7        0.357             2469.714      -1.286
# 126     26           29        0.382             2578.132       0.391
# 127     15           15        0.375             2548.917      -0.078
# 128     11           14        0.391             2611.000       0.919
# 129    211          115        0.610             2381.310       0.046
# 130    179           89        0.609             2381.786       0.002
# 131     32           25        0.598             2387.069       0.188
# 132     97           20        0.748             2225.243      -0.146
# 133     67           19        0.739             2215.080      -0.328
# 134     30            1        0.775             2254.014       0.368
# 135     34           17        0.477             2449.369      -0.338
# 136     27           16        0.443             2452.094      -0.674
# 137      7            1        0.625             2437.333       1.142
# 138     55           50        0.404             2565.492       0.728
# 139     23           15        0.500             2526.151       1.319
# 140     32           34        0.342             2593.092       0.364
# 141    186           87        0.615             2351.154       0.070
# 142    117           50        0.647             2309.700      -0.103
# 143     69           36        0.557             2429.925       0.425
# 144     75           18        0.662             2412.360      -0.245
# 145     65           16        0.658             2432.239      -0.068
# 146     10            2        0.682             2284.045      -1.382
# 147     46           13        0.500             2535.944      -0.222
# 148     46           13        0.500             2535.944      -0.222
# 149      0            0          NaN                  NaN         NaN
# 150      5            1        0.417             2671.667       0.917
# 151      1            0        0.500             2628.000       1.100
# 152      4            1        0.400             2680.400       0.880
# 153    126           32        0.607             2455.558      -0.209
# 154    112           29        0.605             2467.879      -0.114
# 155     14            3        0.630             2357.444      -0.963
# 156    141           45        0.676             2359.563      -0.318
# 157    123           37        0.672             2356.553      -0.365
# 158     18            8        0.696             2375.214      -0.130
# 159     77           44        0.537             2508.854       0.275
# 160     67           40        0.538             2506.050       0.286
# 161     10            4        0.526             2532.316       0.189
# 162     26           22        0.375             2606.536       0.062
# 163     19            9        0.456             2571.176       0.632
# 164      7           13        0.250             2661.182      -0.818
# 165    244          111        0.606             2427.929      -0.104
# 166    209           86        0.614             2419.570      -0.086
# 167     35           25        0.562             2470.845      -0.224
# 168    103            9        0.709             2382.490       0.063
# 169     96            8        0.702             2380.543      -0.016
# 170      7            1        0.775             2400.800       0.810
# 171     72           15        0.495             2530.822      -0.237
# 172     69           14        0.500             2529.474      -0.205
# 173      3            1        0.375             2563.500      -1.000
# 174      9           10        0.275             2675.950      -0.495
# 175      0            0          NaN                  NaN         NaN
# 176      9           10        0.275             2675.950      -0.495
# 177    184           34        0.617             2445.866      -0.063
# 178    165           22        0.633             2431.232      -0.081
# 179     19           12        0.511             2540.659       0.052
# 180     99           32        0.756             2285.156       0.009
# 181     74           19        0.745             2289.741      -0.093
# 182     24           13        0.775             2277.640       0.208
# 183     72           18        0.568             2502.912       0.565
# 184     61           13        0.569             2508.297       0.563
# 185     11            5        0.562             2480.250       0.571
# 186     40           40        0.368             2616.274       0.519
# 187      4            3        0.444             2539.000       0.500
# 188     36           37        0.360             2624.360       0.521
# 189    211           90        0.647             2391.069       0.222
# 190    139           35        0.683             2363.430       0.124
# 191     71           55        0.590             2434.566       0.369
# 192    154           19        0.685             2384.590      -0.147
# 193    133           17        0.686             2382.541      -0.140
# 194     19            2        0.681             2397.194      -0.178
# 195    111           20        0.522             2526.519       0.160
# 196    107           17        0.524             2525.264       0.168
# 197      4            3        0.500             2545.100       0.050
# 198     15           10        0.375             2644.000       0.189
# 199      8            1        0.500             2599.100       1.000
# 200      7            9        0.306             2668.944      -0.261
# 201    280           49        0.615             2445.055      -0.029
# 202    248           35        0.625             2437.467      -0.006
# 203     30           14        0.547             2496.734      -0.166
# 204    118           29        0.697             2368.086      -0.093
# 205    109           26        0.689             2369.247      -0.141
# 206      8            3        0.767             2355.233       0.357
# 207    102           25        0.479             2518.452      -0.367
# 208     86           25        0.469             2516.969      -0.476
# 209     16            0        0.556             2529.000       0.406
# 210     24           16        0.333             2664.143      -0.110
# 211      8            4        0.385             2637.769       0.100
# 212     16           12        0.310             2675.966      -0.203
# 213    244           70        0.598             2440.027      -0.178
# 214    203           55        0.609             2425.245      -0.240
# 215     40           15        0.545             2516.649       0.157
# 216    139           34        0.735             2278.987      -0.017
# 217    119           28        0.725             2282.280      -0.090
# 218     18            6        0.776             2273.433       0.376
# 219    116           37        0.484             2465.435      -0.189
# 220    102           30        0.481             2464.571      -0.214
# 221     14            7        0.481             2472.444      -0.215
# 222     66           61        0.314             2594.022      -0.203
# 223     34           22        0.350             2542.850      -0.363
# 224     32           39        0.286             2633.896      -0.078
# 225    321          132        0.589             2387.941      -0.097
# 226    255           80        0.611             2364.811      -0.157
# 227     64           52        0.509             2467.170       0.078
# 228    120           34        0.674             2258.681      -0.565
# 229     90           29        0.654             2268.136      -0.664
# 230     20            4        0.696             2222.565      -0.654
# 231     56           20        0.525             2454.713       0.148
# 232     50           18        0.522             2455.556       0.127
# 233      6            2        0.500             2450.200      -0.090
# 234     25           26        0.379             2571.387       0.303
# 235     14            9        0.500             2536.375       1.084
# 236     11           17        0.250             2608.733      -0.530
# 237    201           80        0.600             2345.570      -0.286
# 238    154           56        0.604             2343.884      -0.285
# 239     37           23        0.517             2383.744      -0.545
# 240     46           12        0.706             2269.387      -0.269
# 241     39            9        0.715             2269.370      -0.169
# 242      7            3        0.658             2269.474      -0.795
# 243     42           15        0.471             2464.706      -0.249
# 244     26            9        0.488             2453.953      -0.156
# 245     16            6        0.440             2483.200      -0.408
# 246     25           19        0.315             2571.870      -0.276
# 247     14            8        0.318             2535.773      -0.632
# 248     11           11        0.312             2604.958       0.050
# 249    113           46        0.560             2386.107      -0.264
# 250     79           26        0.603             2352.994      -0.227
# 251     34           20        0.456             2466.456      -0.354
# 252    136           48        0.730             2283.128       0.062
# 253     95           32        0.735             2279.493       0.113
# 254     41           16        0.715             2293.625      -0.080
# 255     46           38        0.500             2463.066      -0.038
# 256     34           26        0.533             2458.054       0.285
# 257     12           12        0.400             2478.433      -1.027
# 258     58           39        0.429             2570.244       0.800
# 259     22            9        0.487             2527.692       1.151
# 260     35           30        0.399             2592.291       0.619
# 261    240          125        0.635             2366.763       0.175
# 262    151           67        0.669             2340.067       0.244
# 263     88           58        0.570             2416.574       0.033
# 264    116           46        0.696             2280.564      -0.400
# 265     86           34        0.664             2280.472      -0.678
# 266     30           12        0.757             2278.964       0.105
# 267     72           24        0.508             2455.926       0.020
# 268     64           22        0.486             2457.162      -0.200
# 269      8            2        0.647             2448.294       1.376
# 270     37           44        0.342             2592.326       0.051
# 271     18           17        0.381             2538.190      -0.019
# 272     19           27        0.311             2635.226       0.106
# 273    225          114        0.595             2371.819      -0.232
# 274    168           73        0.582             2358.601      -0.471
# 275     57           41        0.616             2399.188       0.225
# 276    115           28        0.736             2326.481       0.052
# 277    100           24        0.738             2324.613       0.050
# 278     15            4        0.726             2339.024       0.067
# 279     94           41        0.491             2520.983      -0.079
# 280     92           41        0.482             2521.804      -0.163
# 281      2            0        0.800             2493.400       2.760
# 282     24           20        0.396             2628.019       0.551
# 283     12            6        0.429             2571.190       0.224
# 284     12           14        0.375             2665.312       0.766
# 285    233           89        0.626             2416.718       0.059
# 286    204           71        0.633             2405.943      -0.018
# 287     29           18        0.589             2480.962       0.520
# 288     46           18        0.756             2237.256       0.221
# 289     32            7        0.747             2258.088       0.282
# 290     14           11        0.766             2212.636       0.148
# 291     45           17        0.546             2454.920       0.423
# 292     35           14        0.530             2460.910       0.242
# 293     10            3        0.600             2434.850       1.030
# 294     60           75        0.340             2569.465       0.042
# 295     26           22        0.352             2530.815      -0.450
# 296     34           53        0.333             2589.343       0.295
# 297    151          110        0.552             2410.585       0.195
# 298     93           43        0.578             2391.656       0.083
# 299     58           67        0.525             2430.450       0.312
# 300     32           24        0.658             2285.291      -0.903
# 301     32           21        0.637             2286.657      -1.077
# 302      0            3        0.800             2276.000       0.287
# 303     18            9        0.609             2496.370       1.085
# 304     18            9        0.609             2496.370       1.085
# 305      0            0          NaN                  NaN         NaN
# 306      9           11        0.262             2570.238      -1.343
# 307      8           10        0.263             2568.632      -1.342
# 308      1            1        0.250             2585.500      -1.350
# 309     59           44        0.601             2370.582      -0.456
# 310     58           40        0.587             2376.503      -0.512
# 311      1            4        0.735             2312.412       0.094
# 312     58           31        0.750             2262.533       0.050
# 313     42           17        0.768             2271.744       0.269
# 314     16           13        0.712             2250.986      -0.378
# 315     50           21        0.578             2463.073       0.798
# 316     41           16        0.580             2461.816       0.917
# 317      9            5        0.568             2468.045       0.327
# 318     55           38        0.430             2558.930       1.318
# 319     23            9        0.512             2511.238       2.650
# 320     32           29        0.384             2586.370       0.552
# 321    163           90        0.630             2383.103       0.540
# 322    106           42        0.676             2362.512       0.803
# 323     57           47        0.551             2425.143       0.118

# %% [markdown]
# ## 4. Gesamtzeitraum — aggregiert über alle Spielerinnen
#
# Die "Executive Summary"-Tabelle: 4 Buckets (schwächer/gleich/stärker + **Gesamt** als Summe der drei Stärke-Gruppen) × 3 Geschlechts-Gruppen = 12 Zeilen. Die `Gesamt`-Bucket-Zeilen beantworten dabei auch die stärke-unabhängige Frage "schneiden die Top-20-Frauen gegen Männer anders ab als gegen Frauen, über alle Partien hinweg?" — eine separate Tabelle ohne Stärke-Split ist dafür nicht mehr nötig.

# %%
full_index_overall = pd.MultiIndex.from_product(
    [BUCKET_ORDER_FULL, SEX_GROUP_ORDER], names=['strength_bucket', 'sex_group']
)
agg_overall = (
    build_table(games_full, ['strength_bucket', 'sex_group'])
    .set_index(['strength_bucket', 'sex_group'])
    .reindex(full_index_overall)
)
agg_overall[N_COLS] = agg_overall[N_COLS].fillna(0).astype(int)
agg_overall = agg_overall.reset_index()
agg_overall.round(4)
# Out:
#    strength_bucket sex_group  n_partien  siege  remis  niederlagen  \
# 0        schwächer    Gesamt       7478   3936   2747          795
# 1        schwächer         F       5858   2980   2249          629
# 2        schwächer         M       1494    881    460          153
# 3           gleich    Gesamt       3262    798   1776          688
# 4           gleich         F       2806    680   1547          579
# 5           gleich         M        443    112    225          106
# 6          stärker    Gesamt       2224    301   1033          890
# 7          stärker         F        736    122    377          237
# 8          stärker         M       1482    179    653          650
# 9           Gesamt    Gesamt      12964   5035   5556         2373
# 10          Gesamt         F       9400   3782   4173         1445
# 11          Gesamt         M       3419   1172   1338          909
#
#     punktequote  avg_opponent_rating  mean_delta
# 0        0.7100            2310.9913     -0.1547
# 1        0.7007            2316.1978     -0.2122
# 2        0.7436            2294.5803      0.0566
# 3        0.5169            2492.2863      0.1066
# 4        0.5180            2490.2010      0.1093
# 5        0.5068            2507.6953      0.0716
# 6        0.3676            2599.8521      0.3054
# 7        0.4219            2543.6060      0.4387
# 8        0.3411            2628.0256      0.2443
# 9        0.6027            2406.1634     -0.0100
# 10       0.6243            2385.9452     -0.0653
# 11       0.5385            2466.7289      0.1399

# %% [markdown]
# ## 5. Chart — Punktequote je Bucket × Gegner-Geschlecht (Gesamtzeitraum)

# %%
plot_data = agg_overall[agg_overall.sex_group.isin(['F', 'M'])]
fig, ax = plt.subplots(figsize=(9, 5))
sns.barplot(
    data=plot_data, x='strength_bucket', order=BUCKET_ORDER_FULL,
    y='punktequote', hue='sex_group', hue_order=['F', 'M'],
    palette={'F': '#c0587e', 'M': '#4a7ab5'}, ax=ax,
)
ax.axhline(0.5, color='grey', lw=1, ls='--')
ax.set_xlabel('Gegnerstärke-Bucket (± 50 Elo, "Gesamt" = alle drei zusammen)')
ax.set_ylabel('Punktequote')
ax.set_title('Punktequote je Stärke-Bucket × Gegner-Geschlecht, Gesamtzeitraum (2400+-Fenster)')
ax.legend(title='Gegner')
plt.tight_layout(); plt.show()

# %% [markdown]
# ## 6. Pro Jahr — aggregiert über alle Spielerinnen

# %%
years_present = sorted(games['year'].unique())
full_index_year = pd.MultiIndex.from_product(
    [years_present, BUCKET_ORDER_FULL, SEX_GROUP_ORDER],
    names=['year', 'strength_bucket', 'sex_group'],
)
agg_by_year = (
    build_table(games_full, ['year', 'strength_bucket', 'sex_group'])
    .set_index(['year', 'strength_bucket', 'sex_group'])
    .reindex(full_index_year)
)
agg_by_year[N_COLS] = agg_by_year[N_COLS].fillna(0).astype(int)
agg_by_year = agg_by_year.reset_index()
agg_by_year.round(4)
# Out:
#      year strength_bucket sex_group  n_partien  siege  remis  niederlagen  \
# 0    2016       schwächer    Gesamt       1005    558    337          110
# 1    2016       schwächer         F        754    398    272           84
# 2    2016       schwächer         M        229    148     57           24
# 3    2016          gleich    Gesamt        377     97    198           82
# 4    2016          gleich         F        302     82    158           62
# 5    2016          gleich         M         73     13     40           20
# 6    2016         stärker    Gesamt        357     46    164          147
# 7    2016         stärker         F        113     23     55           35
# 8    2016         stärker         M        243     23    109          111
# 9    2016          Gesamt    Gesamt       1739    701    699          339
# 10   2016          Gesamt         F       1169    503    485          181
# 11   2016          Gesamt         M        545    184    206          155
# 12   2017       schwächer    Gesamt        952    526    337           89
# 13   2017       schwächer         F        747    389    284           74
# 14   2017       schwächer         M        186    127     46           13
# 15   2017          gleich    Gesamt        254     73    124           57
# 16   2017          gleich         F        193     53     97           43
# 17   2017          gleich         M         58     18     26           14
# 18   2017         stärker    Gesamt        249     32    121           96
# 19   2017         stärker         F         62     10     36           16
# 20   2017         stärker         M        187     22     85           80
# 21   2017          Gesamt    Gesamt       1455    631    582          242
# 22   2017          Gesamt         F       1002    452    417          133
# 23   2017          Gesamt         M        431    167    157          107
# 24   2018       schwächer    Gesamt       1008    562    341          105
# 25   2018       schwächer         F        763    428    257           78
# 26   2018       schwächer         M        226    121     78           27
# 27   2018          gleich    Gesamt        294     71    159           64
# 28   2018          gleich         F        235     55    129           51
# 29   2018          gleich         M         58     15     30           13
# 30   2018         stärker    Gesamt        250     41    107          102
# 31   2018         stärker         F         67     19     28           20
# 32   2018         stärker         M        182     22     78           82
# 33   2018          Gesamt    Gesamt       1552    674    607          271
# 34   2018          Gesamt         F       1065    502    414          149
# 35   2018          Gesamt         M        466    158    186          122
# 36   2019       schwächer    Gesamt        908    479    346           83
# 37   2019       schwächer         F        715    369    277           69
# 38   2019       schwächer         M        177    103     64           10
# 39   2019          gleich    Gesamt        431    119    223           89
# 40   2019          gleich         F        391    107    201           83
# 41   2019          gleich         M         39     11     22            6
# 42   2019         stärker    Gesamt        273     28    133          112
# 43   2019         stärker         F         73      6     40           27
# 44   2019         stärker         M        198     22     92           84
# 45   2019          Gesamt    Gesamt       1612    626    702          284
# 46   2019          Gesamt         F       1179    482    518          179
# 47   2019          Gesamt         M        414    136    178          100
# 48   2020       schwächer    Gesamt        313    160    112           41
# 49   2020       schwächer         F        214     99     86           29
# 50   2020       schwächer         M         92     55     25           12
# 51   2020          gleich    Gesamt        212     50    114           48
# 52   2020          gleich         F        198     46    108           44
# 53   2020          gleich         M         13      4      6            3
# 54   2020         stärker    Gesamt        137     19     62           56
# 55   2020         stärker         F         62      8     28           26
# 56   2020         stärker         M         75     11     34           30
# 57   2020          Gesamt    Gesamt        662    229    288          145
# 58   2020          Gesamt         F        474    153    222           99
# 59   2020          Gesamt         M        180     70     65           45
# 60   2021       schwächer    Gesamt        568    316    197           55
# 61   2021       schwächer         F        474    249    180           45
# 62   2021       schwächer         M         80     56     16            8
# 63   2021          gleich    Gesamt        278     73    141           64
# 64   2021          gleich         F        245     65    124           56
# 65   2021          gleich         M         31      8     17            6
# 66   2021         stärker    Gesamt        193     36     89           68
# 67   2021         stärker         F         83     15     41           27
# 68   2021         stärker         M        108     21     47           40
# 69   2021          Gesamt    Gesamt       1039    425    427          187
# 70   2021          Gesamt         F        802    329    345          128
# 71   2021          Gesamt         M        219     85     80           54
# 72   2022       schwächer    Gesamt        578    292    217           69
# 73   2022       schwächer         F        420    203    170           47
# 74   2022       schwächer         M        144     81     43           20
# 75   2022          gleich    Gesamt        214     59    109           46
# 76   2022          gleich         F        150     44     73           33
# 77   2022          gleich         M         62     15     34           13
# 78   2022         stärker    Gesamt        125     10     59           56
# 79   2022         stärker         F         38      4     24           10
# 80   2022         stärker         M         87      6     35           46
# 81   2022          Gesamt    Gesamt        917    361    385          171
# 82   2022          Gesamt         F        608    251    267           90
# 83   2022          Gesamt         M        293    102    112           79
# 84   2023       schwächer    Gesamt        742    358    299           85
# 85   2023       schwächer         F        651    307    270           74
# 86   2023       schwächer         M         82     46     26           10
# 87   2023          gleich    Gesamt        412     99    234           79
# 88   2023          gleich         F        377     91    215           71
# 89   2023          gleich         M         35      8     19            8
# 90   2023         stärker    Gesamt        217     29    109           79
# 91   2023         stärker         F         95     13     55           27
# 92   2023         stärker         M        122     16     54           52
# 93   2023          Gesamt    Gesamt       1371    486    642          243
# 94   2023          Gesamt         F       1123    411    540          172
# 95   2023          Gesamt         M        239     70     99           70
# 96   2024       schwächer    Gesamt        666    349    256           61
# 97   2024       schwächer         F        481    243    194           44
# 98   2024       schwächer         M        180    103     60           17
# 99   2024          gleich    Gesamt        373     73    231           69
# 100  2024          gleich         F        337     65    214           58
# 101  2024          gleich         M         35      8     16           11
# 102  2024         stärker    Gesamt        195     24     88           83
# 103  2024         stärker         F         43      5     23           15
# 104  2024         stärker         M        152     19     65           68
# 105  2024          Gesamt    Gesamt       1234    446    575          213
# 106  2024          Gesamt         F        861    313    431          117
# 107  2024          Gesamt         M        367    130    141           96
# 108  2025       schwächer    Gesamt        738    336    305           97
# 109  2025       schwächer         F        639    295    259           85
# 110  2025       schwächer         M         98     41     45           12
# 111  2025          gleich    Gesamt        417     84    243           90
# 112  2025          gleich         F        378     72    228           78
# 113  2025          gleich         M         39     12     15           12
# 114  2025         stärker    Gesamt        228     36    101           91
# 115  2025         stärker         F        100     19     47           34
# 116  2025         stärker         M        128     17     54           57
# 117  2025          Gesamt    Gesamt       1383    456    649          278
# 118  2025          Gesamt         F       1117    386    534          197
# 119  2025          Gesamt         M        265     70    114           81
#
#      punktequote  avg_opponent_rating  mean_delta
# 0         0.7229            2319.6597     -0.1015
# 1         0.7082            2319.5186     -0.2505
# 2         0.7707            2318.2795      0.3441
# 3         0.5199            2505.2149      0.1462
# 4         0.5331            2499.6921      0.2586
# 5         0.4521            2530.2329     -0.4438
# 6         0.3585            2621.7507      0.2031
# 7         0.4469            2558.8850      0.6301
# 8         0.3189            2651.2675      0.0173
# 9         0.6041            2421.9028      0.0147
# 10        0.6377            2389.2027     -0.0339
# 11        0.5266            2495.1394      0.0928
# 12        0.7295            2312.7132     -0.0696
# 13        0.7108            2316.2289     -0.2258
# 14        0.8065            2299.7742      0.5753
# 15        0.5315            2495.7677      0.2130
# 16        0.5259            2480.3575      0.1166
# 17        0.5345            2551.3793      0.4069
# 18        0.3715            2636.4016      0.3739
# 19        0.4516            2564.3065      0.7597
# 20        0.3449            2660.3048      0.2460
# 21        0.6337            2400.0632      0.0556
# 22        0.6592            2363.1926     -0.0989
# 23        0.5696            2490.0580      0.4097
# 24        0.7267            2295.8413     -0.1808
# 25        0.7294            2296.6343     -0.1474
# 26        0.7080            2295.2257     -0.3991
# 27        0.5119            2490.5646      0.0670
# 28        0.5085            2485.7787      0.0536
# 29        0.5172            2511.1034      0.0466
# 30        0.3780            2595.7720      0.6844
# 31        0.4925            2510.7910      2.0343
# 32        0.3352            2627.6484      0.1835
# 33        0.6298            2381.0419      0.0055
# 34        0.6657            2351.8432      0.0342
# 35        0.5386            2451.9249     -0.1161
# 36        0.7181            2316.5143     -0.0354
# 37        0.7098            2318.9119     -0.0867
# 38        0.7627            2313.6610      0.3198
# 39        0.5348            2487.6543      0.2575
# 40        0.5307            2487.1739      0.2156
# 41        0.5641            2495.1795      0.5718
# 42        0.3462            2610.5531      0.1963
# 43        0.3562            2549.0548     -0.3932
# 44        0.3434            2633.6566      0.4288
# 45        0.6061            2412.0689      0.0822
# 46        0.6285            2388.9635     -0.0054
# 47        0.5435            2483.8019      0.3957
# 48        0.6901            2330.2492     -0.2112
# 49        0.6636            2356.8879     -0.2757
# 50        0.7337            2271.9457     -0.2337
# 51        0.5047            2517.2736      0.0264
# 52        0.5051            2519.1061      0.0263
# 53        0.5385            2497.3846      0.4692
# 54        0.3650            2592.9635      0.1540
# 55        0.3548            2561.4839     -0.3435
# 56        0.3733            2618.9867      0.5653
# 57        0.5634            2444.5106     -0.0595
# 58        0.5570            2451.4114     -0.1584
# 59        0.5694            2432.8278      0.1500
# 60        0.7298            2328.1180      0.2678
# 61        0.7152            2344.0802      0.2129
# 62        0.8000            2245.1625      0.4750
# 63        0.5162            2479.2014      0.1065
# 64        0.5184            2473.1102      0.0927
# 65        0.5323            2533.3226      0.5742
# 66        0.4171            2569.5026      0.6254
# 67        0.4277            2531.1084      0.4928
# 68        0.4120            2599.6852      0.7528
# 69        0.6145            2413.3811      0.2910
# 70        0.6253            2402.8529      0.2051
# 71        0.5708            2460.7854      0.6260
# 72        0.6929            2288.9913     -0.4064
# 73        0.6857            2295.2548     -0.4650
# 74        0.7118            2279.9444     -0.1944
# 75        0.5304            2489.8692      0.2734
# 76        0.5367            2488.9133      0.3133
# 77        0.5161            2496.0484      0.1984
# 78        0.3160            2572.5280     -0.3096
# 79        0.4211            2542.8947      0.3000
# 80        0.2701            2585.4713     -0.5759
# 81        0.6036            2374.5202     -0.2346
# 82        0.6324            2358.5099     -0.2252
# 83        0.5392            2416.3925     -0.2246
# 84        0.6840            2297.7911     -0.4125
# 85        0.6790            2302.9278     -0.4475
# 86        0.7195            2271.8415     -0.0622
# 87        0.5243            2489.5316      0.1692
# 88        0.5265            2488.8408      0.1761
# 89        0.5000            2496.9714      0.0943
# 90        0.3848            2573.2949      0.4078
# 91        0.4263            2547.3789      0.3768
# 92        0.3525            2593.4754      0.4320
# 93        0.5886            2399.0175     -0.1079
# 94        0.6064            2386.0196     -0.1684
# 95        0.5000            2468.9916      0.2130
# 96        0.7162            2301.0045     -0.0530
# 97        0.7069            2304.5738     -0.1447
# 98        0.7389            2294.7333      0.1944
# 99        0.5054            2492.2225     -0.0038
# 100       0.5104            2495.0772      0.0442
# 101       0.4571            2461.5143     -0.4829
# 102       0.3487            2607.0769      0.2472
# 103       0.3837            2533.4651     -0.1000
# 104       0.3388            2627.9013      0.3454
# 105       0.5944            2407.1702      0.0093
# 106       0.6138            2390.5691     -0.0685
# 107       0.5463            2448.6267      0.1924
# 108       0.6619            2329.0285     -0.3844
# 109       0.6643            2334.2911     -0.3080
# 110       0.6480            2295.2347     -0.8786
# 111       0.4928            2484.5180     -0.1300
# 112       0.4921            2486.9815     -0.1246
# 113       0.5000            2460.6410     -0.1821
# 114       0.3794            2581.2149      0.2158
# 115       0.4250            2531.8500      0.3450
# 116       0.3438            2619.7812      0.1148
# 117       0.5644            2417.4866     -0.2087
# 118       0.5846            2403.6491     -0.1875
# 119       0.4792            2476.3396     -0.2962

# %%
plot_year = agg_by_year[agg_by_year.sex_group == 'Gesamt']
fig, ax = plt.subplots(figsize=(10, 5))
for bucket, color in zip(BUCKET_ORDER_FULL, ['#d7191c', '#4a7ab5', '#2a9d3f', '#888888']):
    sub = plot_year[plot_year.strength_bucket == bucket]
    ax.plot(sub['year'], sub['punktequote'], marker='o', label=bucket, color=color)
ax.axhline(0.5, color='grey', lw=1, ls='--')
ax.set_xlabel('Jahr')
ax.set_ylabel('Punktequote')
ax.set_title('Punktequote je Jahr × Stärke-Bucket (alle Gegner, aggregiert über alle Spielerinnen)')
ax.legend(title='Bucket')
plt.tight_layout(); plt.show()

# %% [markdown]
# ## 7. Pro Jahr × Spielerin (Datenwürfel, nur Export)
#
# Wie bei Notebook 16 wird hier **nicht** auf ein volles Raster reindexiert: Jahre vor dem individuellen Schwellenjahr einer Spielerin fehlen zu Recht (sie waren dort noch nicht im 2400+-Fenster), eine erzwungene 0-Zeile wäre irreführend.

# %%
table_by_year = build_table(games_full, ['name', 'year', 'strength_bucket', 'sex_group'])
table_by_year[N_COLS] = table_by_year[N_COLS].astype(int)
table_by_year['strength_bucket'] = pd.Categorical(table_by_year['strength_bucket'], BUCKET_ORDER_FULL, ordered=True)
table_by_year['sex_group'] = pd.Categorical(table_by_year['sex_group'], SEX_GROUP_ORDER, ordered=True)
table_by_year = table_by_year.sort_values(['name', 'year', 'strength_bucket', 'sex_group']).reset_index(drop=True)
print(f'{len(table_by_year):,} Zeilen im vollen Datenwürfel — Beispiel für eine Spielerin:')

demo_name = roster.loc[roster['threshold_year'] == roster['threshold_year'].min(), 'name'].iloc[0]
table_by_year[table_by_year.name == demo_name].round(3)
# Out:
# 2,381 Zeilen im vollen Datenwürfel — Beispiel für eine Spielerin:
#                    name  year strength_bucket sex_group  n_partien  siege  \
# 58   Batsiashvili, Nino  2016       schwächer    Gesamt         48     26
# 59   Batsiashvili, Nino  2016       schwächer         F         31     17
# 60   Batsiashvili, Nino  2016       schwächer         M         15      9
# 61   Batsiashvili, Nino  2016          gleich    Gesamt         21      6
# 62   Batsiashvili, Nino  2016          gleich         F         19      5
# 63   Batsiashvili, Nino  2016          gleich         M          2      1
# 64   Batsiashvili, Nino  2016         stärker    Gesamt         27      4
# 65   Batsiashvili, Nino  2016         stärker         F          8      1
# 66   Batsiashvili, Nino  2016         stärker         M         19      3
# 67   Batsiashvili, Nino  2016          Gesamt    Gesamt         96     36
# 68   Batsiashvili, Nino  2016          Gesamt         F         58     23
# 69   Batsiashvili, Nino  2016          Gesamt         M         36     13
# 70   Batsiashvili, Nino  2017       schwächer    Gesamt         64     37
# 71   Batsiashvili, Nino  2017       schwächer         F         51     28
# 72   Batsiashvili, Nino  2017       schwächer         M         12      9
# 73   Batsiashvili, Nino  2017          gleich    Gesamt         17      5
# 74   Batsiashvili, Nino  2017          gleich         F         16      5
# 75   Batsiashvili, Nino  2017          gleich         M          1      0
# 76   Batsiashvili, Nino  2017         stärker    Gesamt         19      4
# 77   Batsiashvili, Nino  2017         stärker         F          8      3
# 78   Batsiashvili, Nino  2017         stärker         M         11      1
# 79   Batsiashvili, Nino  2017          Gesamt    Gesamt        100     46
# 80   Batsiashvili, Nino  2017          Gesamt         F         75     36
# 81   Batsiashvili, Nino  2017          Gesamt         M         24     10
# 82   Batsiashvili, Nino  2018       schwächer    Gesamt         58     28
# 83   Batsiashvili, Nino  2018       schwächer         F         45     21
# 84   Batsiashvili, Nino  2018       schwächer         M         13      7
# 85   Batsiashvili, Nino  2018          gleich    Gesamt          7      2
# 86   Batsiashvili, Nino  2018          gleich         F          7      2
# 87   Batsiashvili, Nino  2018         stärker    Gesamt         11      3
# 88   Batsiashvili, Nino  2018         stärker         F          1      0
# 89   Batsiashvili, Nino  2018         stärker         M         10      3
# 90   Batsiashvili, Nino  2018          Gesamt    Gesamt         76     33
# 91   Batsiashvili, Nino  2018          Gesamt         F         53     23
# 92   Batsiashvili, Nino  2018          Gesamt         M         23     10
# 93   Batsiashvili, Nino  2019       schwächer    Gesamt         43     23
# 94   Batsiashvili, Nino  2019       schwächer         F         37     20
# 95   Batsiashvili, Nino  2019       schwächer         M          5      3
# 96   Batsiashvili, Nino  2019          gleich    Gesamt         26      7
# 97   Batsiashvili, Nino  2019          gleich         F         21      6
# 98   Batsiashvili, Nino  2019          gleich         M          4      0
# 99   Batsiashvili, Nino  2019         stärker    Gesamt         18      1
# 100  Batsiashvili, Nino  2019         stärker         F          3      0
# 101  Batsiashvili, Nino  2019         stärker         M         15      1
# 102  Batsiashvili, Nino  2019          Gesamt    Gesamt         87     31
# 103  Batsiashvili, Nino  2019          Gesamt         F         61     26
# 104  Batsiashvili, Nino  2019          Gesamt         M         24      4
# 105  Batsiashvili, Nino  2020       schwächer    Gesamt         38     25
# 106  Batsiashvili, Nino  2020       schwächer         F         23     14
# 107  Batsiashvili, Nino  2020       schwächer         M         15     11
# 108  Batsiashvili, Nino  2020          gleich    Gesamt          8      3
# 109  Batsiashvili, Nino  2020          gleich         F          3      1
# 110  Batsiashvili, Nino  2020          gleich         M          5      2
# 111  Batsiashvili, Nino  2020         stärker    Gesamt         12      2
# 112  Batsiashvili, Nino  2020         stärker         M         12      2
# 113  Batsiashvili, Nino  2020          Gesamt    Gesamt         58     30
# 114  Batsiashvili, Nino  2020          Gesamt         F         26     15
# 115  Batsiashvili, Nino  2020          Gesamt         M         32     15
# 116  Batsiashvili, Nino  2021       schwächer    Gesamt         41     25
# 117  Batsiashvili, Nino  2021       schwächer         F         34     19
# 118  Batsiashvili, Nino  2021       schwächer         M          7      6
# 119  Batsiashvili, Nino  2021          gleich    Gesamt         14      1
# 120  Batsiashvili, Nino  2021          gleich         F         11      1
# 121  Batsiashvili, Nino  2021          gleich         M          3      0
# 122  Batsiashvili, Nino  2021         stärker    Gesamt          9      3
# 123  Batsiashvili, Nino  2021         stärker         M          9      3
# 124  Batsiashvili, Nino  2021          Gesamt    Gesamt         64     29
# 125  Batsiashvili, Nino  2021          Gesamt         F         45     20
# 126  Batsiashvili, Nino  2021          Gesamt         M         19      9
# 127  Batsiashvili, Nino  2022       schwächer    Gesamt         84     50
# 128  Batsiashvili, Nino  2022       schwächer         F         66     40
# 129  Batsiashvili, Nino  2022       schwächer         M         18     10
# 130  Batsiashvili, Nino  2022          gleich    Gesamt         17      8
# 131  Batsiashvili, Nino  2022          gleich         F         10      7
# 132  Batsiashvili, Nino  2022          gleich         M          7      1
# 133  Batsiashvili, Nino  2022         stärker    Gesamt          7      1
# 134  Batsiashvili, Nino  2022         stärker         F          2      1
# 135  Batsiashvili, Nino  2022         stärker         M          5      0
# 136  Batsiashvili, Nino  2022          Gesamt    Gesamt        108     59
# 137  Batsiashvili, Nino  2022          Gesamt         F         78     48
# 138  Batsiashvili, Nino  2022          Gesamt         M         30     11
# 139  Batsiashvili, Nino  2023       schwächer    Gesamt         51     22
# 140  Batsiashvili, Nino  2023       schwächer         F         47     22
# 141  Batsiashvili, Nino  2023       schwächer         M          4      0
# 142  Batsiashvili, Nino  2023          gleich    Gesamt         24      7
# 143  Batsiashvili, Nino  2023          gleich         F         24      7
# 144  Batsiashvili, Nino  2023         stärker    Gesamt          5      0
# 145  Batsiashvili, Nino  2023         stärker         F          5      0
# 146  Batsiashvili, Nino  2023          Gesamt    Gesamt         80     29
# 147  Batsiashvili, Nino  2023          Gesamt         F         76     29
# 148  Batsiashvili, Nino  2023          Gesamt         M          4      0
# 149  Batsiashvili, Nino  2024       schwächer    Gesamt         51     33
# 150  Batsiashvili, Nino  2024       schwächer         F         40     25
# 151  Batsiashvili, Nino  2024       schwächer         M         10      8
# 152  Batsiashvili, Nino  2024          gleich    Gesamt         13      2
# 153  Batsiashvili, Nino  2024          gleich         F         11      2
# 154  Batsiashvili, Nino  2024          gleich         M          2      0
# 155  Batsiashvili, Nino  2024         stärker    Gesamt          5      0
# 156  Batsiashvili, Nino  2024         stärker         F          1      0
# 157  Batsiashvili, Nino  2024         stärker         M          4      0
# 158  Batsiashvili, Nino  2024          Gesamt    Gesamt         69     35
# 159  Batsiashvili, Nino  2024          Gesamt         F         52     27
# 160  Batsiashvili, Nino  2024          Gesamt         M         16      8
# 161  Batsiashvili, Nino  2025       schwächer    Gesamt         42     19
# 162  Batsiashvili, Nino  2025       schwächer         F         38     16
# 163  Batsiashvili, Nino  2025       schwächer         M          4      3
# 164  Batsiashvili, Nino  2025          gleich    Gesamt         22      9
# 165  Batsiashvili, Nino  2025          gleich         F         13      3
# 166  Batsiashvili, Nino  2025          gleich         M          9      6
# 167  Batsiashvili, Nino  2025         stärker    Gesamt          7      2
# 168  Batsiashvili, Nino  2025         stärker         F          5      2
# 169  Batsiashvili, Nino  2025         stärker         M          2      0
# 170  Batsiashvili, Nino  2025          Gesamt    Gesamt         71     30
# 171  Batsiashvili, Nino  2025          Gesamt         F         56     21
# 172  Batsiashvili, Nino  2025          Gesamt         M         15      9
#
#      remis  niederlagen  punktequote  avg_opponent_rating  mean_delta
# 58      13            9        0.677             2275.396      -0.700
# 59       7            7        0.661             2264.258      -0.984
# 60       5            1        0.767             2278.333       0.253
# 61       9            6        0.500             2485.667       0.062
# 62       8            6        0.474             2487.632      -0.184
# 63       1            0        0.750             2467.000       2.400
# 64      13           10        0.389             2614.333       0.622
# 65       6            1        0.500             2557.250       1.050
# 66       7            9        0.342             2638.368       0.442
# 67      35           25        0.557             2416.719      -0.161
# 68      21           14        0.578             2377.845      -0.441
# 69      13           10        0.542             2478.833       0.472
# 70      21            6        0.742             2298.719       0.180
# 71      19            4        0.735             2315.451       0.276
# 72       2            1        0.833             2218.250       0.300
# 73       7            5        0.500             2468.647      -0.212
# 74       6            5        0.500             2470.438      -0.194
# 75       1            0        0.500             2440.000      -0.500
# 76       6            9        0.368             2625.684       0.584
# 77       1            4        0.438             2583.750       0.725
# 78       5            5        0.318             2656.182       0.482
# 79      34           20        0.630             2389.730       0.190
# 80      26           13        0.653             2377.133       0.224
# 81       8            6        0.583             2428.208       0.350
# 82      21            9        0.664             2301.379      -0.769
# 83      18            6        0.667             2299.089      -0.776
# 84       3            3        0.654             2309.308      -0.746
# 85       3            2        0.500             2468.714      -0.329
# 86       3            2        0.500             2468.714      -0.329
# 87       2            6        0.364             2638.182       0.418
# 88       0            1        0.000             2654.000      -3.300
# 89       2            5        0.400             2636.600       0.790
# 90      26           17        0.605             2365.539      -0.557
# 91      21            9        0.632             2328.189      -0.764
# 92       5            8        0.543             2451.609      -0.078
# 93      15            5        0.709             2268.023      -0.088
# 94      12            5        0.703             2274.432      -0.073
# 95       2            0        0.800             2255.200       0.540
# 96      15            4        0.558             2432.346       0.631
# 97      12            3        0.571             2429.810       0.733
# 98       3            1        0.375             2458.250      -0.850
# 99       4           13        0.167             2579.944      -1.400
# 100      1            2        0.167             2517.667      -2.033
# 101      3           11        0.167             2592.400      -1.273
# 102     34           22        0.552             2381.667      -0.145
# 103     25           10        0.631             2339.885       0.108
# 104      8           12        0.333             2499.792      -0.825
# 105      8            5        0.763             2245.737       0.084
# 106      5            4        0.717             2262.565      -0.204
# 107      3            1        0.833             2219.933       0.527
# 108      4            1        0.625             2456.125       1.175
# 109      2            0        0.667             2453.667       1.633
# 110      2            1        0.600             2457.600       0.900
# 111      4            6        0.333             2618.583       0.492
# 112      4            6        0.333             2618.583       0.492
# 113     16           12        0.655             2351.897       0.319
# 114      7            4        0.712             2284.615       0.008
# 115      9            8        0.609             2406.562       0.572
# 116     13            3        0.768             2318.293       0.651
# 117     12            3        0.735             2334.324       0.447
# 118      1            0        0.929             2240.429       1.643
# 119      9            4        0.393             2471.714      -1.200
# 120      6            4        0.364             2469.000      -1.591
# 121      3            0        0.500             2481.667       0.233
# 122      3            3        0.500             2588.333       1.633
# 123      3            3        0.500             2588.333       1.633
# 124     25           10        0.648             2389.828       0.384
# 125     18            7        0.644             2367.244      -0.051
# 126      7            3        0.658             2443.316       1.416
# 127     23           11        0.732             2262.179      -0.115
# 128     18            8        0.742             2257.576      -0.048
# 129      5            3        0.694             2279.056      -0.361
# 130      5            4        0.618             2462.824       1.065
# 131      2            1        0.800             2459.300       2.910
# 132      3            3        0.357             2467.857      -1.571
# 133      1            5        0.214             2596.714      -1.100
# 134      1            0        0.750             2523.000       3.300
# 135      0            5        0.000             2626.200      -2.860
# 136     29           20        0.681             2315.444       0.006
# 137     21            9        0.750             2290.244       0.417
# 138      8           11        0.500             2380.967      -1.060
# 139     20            9        0.627             2272.765      -1.061
# 140     17            8        0.649             2260.957      -0.966
# 141      3            1        0.375             2411.500      -2.175
# 142     13            4        0.562             2480.083       0.642
# 143     13            4        0.562             2480.083       0.642
# 144      3            2        0.300             2565.200      -0.880
# 145      3            2        0.300             2565.200      -0.880
# 146     36           15        0.588             2353.238      -0.539
# 147     33           14        0.599             2350.171      -0.453
# 148      3            1        0.375             2411.500      -2.175
# 149     15            3        0.794             2248.098       0.518
# 150     12            3        0.775             2242.700       0.292
# 151      2            0        0.900             2275.200       1.790
# 152      8            3        0.462             2463.462      -0.246
# 153      7            2        0.500             2462.364       0.109
# 154      1            1        0.250             2469.500      -2.200
# 155      4            1        0.400             2549.800       0.300
# 156      1            0        0.500             2533.000       0.900
# 157      3            1        0.375             2554.000       0.150
# 158     27            7        0.703             2310.536       0.358
# 159     20            5        0.712             2294.750       0.265
# 160      6            2        0.688             2369.188       0.881
# 161     12           11        0.595             2320.571      -0.929
# 162     11           11        0.566             2318.316      -1.268
# 163      1            0        0.875             2342.000       2.300
# 164      7            6        0.568             2451.364       0.541
# 165      6            4        0.462             2458.077      -0.454
# 166      1            2        0.722             2441.667       1.978
# 167      4            1        0.571             2564.714       2.057
# 168      3            0        0.700             2555.000       3.240
# 169      1            1        0.250             2589.000      -0.900
# 170     23           18        0.585             2385.169      -0.179
# 171     20           15        0.554             2371.893      -0.677
# 172      3            3        0.700             2434.733       1.680

# %% [markdown]
# ## 8. Signifikanztest — gleich starke Gegner, Frauen vs. Männer (Spieler-Ebene)
#
# Wie in Notebook 16: Permutationstest auf **Spieler-Ebene** (Ø Punktequote pro `fide_id`, nicht pro Partie), um den Cluster-Effekt durch stark ungleiche Partienzahlen pro Person zu vermeiden. 10.000 Permutationen, fester Seed, kein scipy/statsmodels nötig.

# %%
def permutation_test(a, b, n_perm=10000, seed=42, return_diffs=False):
    rng = np.random.default_rng(seed)
    observed = a.mean() - b.mean()
    pooled = np.concatenate([a, b])
    n_a = len(a)
    diffs = np.empty(n_perm)
    for i in range(n_perm):
        rng.shuffle(pooled)
        diffs[i] = pooled[:n_a].mean() - pooled[n_a:].mean()
    p_value = (np.abs(diffs) >= np.abs(observed)).mean()
    return (observed, p_value, diffs) if return_diffs else (observed, p_value)

gleich = games[games.strength_bucket == 'gleich']
pm_f = gleich[gleich.opponent_sex == 'F'].groupby('fide_id')['result'].mean()
pm_m = gleich[gleich.opponent_sex == 'M'].groupby('fide_id')['result'].mean()
a, b = pm_f.values, pm_m.values
observed, p_value, diffs = permutation_test(a, b, return_diffs=True)

print(f'Spielerinnen mit Partien vs. Frauen (gleich stark): {len(a)}')
print(f'Spielerinnen mit Partien vs. Männer (gleich stark): {len(b)}')
print(f'Ø Punktequote vs. Frauen (Spieler-Mittel): {a.mean():.4f}')
print(f'Ø Punktequote vs. Männer (Spieler-Mittel): {b.mean():.4f}')
print(f'Beobachtete Differenz (Frauen \u2212 Männer): {observed:+.4f}')
print(f'Permutations-p-Wert (10.000 Permutationen, zweiseitig): {p_value:.4f}')
if min(len(a), len(b)) < 8:
    print('Achtung: underpowered (< 8 Spielerinnen in einer Gruppe)')
# Out:
# Spielerinnen mit Partien vs. Frauen (gleich stark): 26
# Spielerinnen mit Partien vs. Männer (gleich stark): 25
# Ø Punktequote vs. Frauen (Spieler-Mittel): 0.5217
# Ø Punktequote vs. Männer (Spieler-Mittel): 0.4897
# Beobachtete Differenz (Frauen − Männer): +0.0320
# Permutations-p-Wert (10.000 Permutationen, zweiseitig): 0.2863

# %%
fig, ax = plt.subplots()
ax.hist(diffs, bins=50, color='#888888', alpha=0.8)
ax.axvline(observed, color='#c0587e', lw=2,
           label=f'beobachtet ({observed:+.3f}), p={p_value:.4f}')
ax.axvline(0, color='grey', lw=1, ls='--')
ax.set_title('Permutations-Nullverteilung: gleich starke Gegner, Frauen vs. Männer (Spieler-Ebene)')
ax.set_xlabel('Differenz der Spieler-Mittelwerte der Punktequote (vs. Frauen \u2212 vs. Männer)')
ax.legend()
plt.tight_layout(); plt.show()

# %% [markdown]
# ### Robustheits-Check: Mindestanzahl Partien pro Spielerin
#
# Bei `min_n=1` zählt eine Spielerin mit nur 1–4 Partien vs. Männer genauso viel wie eine mit vielen — ihr persönlicher Mittelwert ist dann extrem verrauscht. Sweep über eine Mindest-Partienzahl pro Spielerin prüft, ob der Effekt robust ist oder von genau diesen dünn besetzten Zellen getrieben wird.

# %%
pm_f_full = gleich[gleich.opponent_sex == 'F'].groupby('fide_id')['result'].agg(['mean', 'count'])
pm_m_full = gleich[gleich.opponent_sex == 'M'].groupby('fide_id')['result'].agg(['mean', 'count'])

sweep_rows = []
for min_n in [1, 5, 8, 10]:
    a_s = pm_f_full[pm_f_full['count'] >= min_n]['mean'].values
    b_s = pm_m_full[pm_m_full['count'] >= min_n]['mean'].values
    obs_s, p_s = permutation_test(a_s, b_s)
    sweep_rows.append({
        'min_partien_pro_spielerin': min_n, 'n_spielerinnen_f': len(a_s), 'n_spielerinnen_m': len(b_s),
        'mean_f': round(a_s.mean(), 4), 'mean_m': round(b_s.mean(), 4),
        'differenz': round(obs_s, 4), 'p_wert': round(p_s, 4),
    })
pd.DataFrame(sweep_rows)
# Out:
#    min_partien_pro_spielerin  n_spielerinnen_f  n_spielerinnen_m  mean_f  \
# 0                          1                26                25  0.5217
# 1                          5                26                22  0.5217
# 2                          8                26                21  0.5217
# 3                         10                26                19  0.5217
#
#    mean_m  differenz  p_wert
# 0  0.4897     0.0320  0.2863
# 1  0.5243    -0.0026  0.9126
# 2  0.5112     0.0105  0.5895
# 3  0.5120     0.0097  0.6298

# %% [markdown]
# ## Export
#
# CSVs landen (wie bei Notebook 16) relativ im Ausführungsverzeichnis (`notebooks/`, per `.gitignore` ausgeschlossen). `top20_2400_overall_by_sex.csv` wird direkt aus der `Gesamt`-Bucket-Zeile von Tabelle 4 abgeleitet (kein separater Rechenweg mehr nötig, siehe Abschnitt 4).

# %%
agg_overall_no_bucket = (
    agg_overall[agg_overall.strength_bucket == 'Gesamt']
    .drop(columns='strength_bucket')
    .set_index('sex_group')
    .reindex(SEX_GROUP_ORDER)
    .reset_index()
)

year_pivot.to_csv('top20_2400_games_per_year.csv')
table_overall.to_csv('top20_2400_strength_summary_overall_per_player.csv', index=False)
agg_overall.to_csv('top20_2400_strength_summary_overall_aggregate.csv', index=False)
agg_overall_no_bucket.to_csv('top20_2400_overall_by_sex.csv', index=False)
agg_by_year.to_csv('top20_2400_strength_summary_by_year_aggregate.csv', index=False)
table_by_year.to_csv('top20_2400_strength_summary_by_year_per_player.csv', index=False)
print('wrote 6 CSVs: top20_2400_games_per_year.csv, top20_2400_strength_summary_overall_per_player.csv, '
      'top20_2400_strength_summary_overall_aggregate.csv, top20_2400_overall_by_sex.csv, '
      'top20_2400_strength_summary_by_year_aggregate.csv, top20_2400_strength_summary_by_year_per_player.csv')
# Out:
# wrote 6 CSVs: top20_2400_games_per_year.csv, top20_2400_strength_summary_overall_per_player.csv, top20_2400_strength_summary_overall_aggregate.csv, top20_2400_overall_by_sex.csv, top20_2400_strength_summary_by_year_aggregate.csv, top20_2400_strength_summary_by_year_per_player.csv

# %% [markdown]
# ## Fazit
#
# Tabelle 4 (Abschnitt 4) beantwortet die Kernfrage direkt: schneiden die Top-20-Frauen im 2400+-Fenster gegen gleich starke/stärkere/schwächere Männer anders ab als gegen ebenso eingestufte Frauen? Die zusätzliche `Gesamt`-Bucket-Zeile zeigt denselben Vergleich ohne die Stärke-Differenzierung — nur noch Gesamt/vs. Frauen/vs. Männer über alle Partien hinweg, unabhängig vom relativen Stärkeverhältnis. Tabelle 3 (pro Spielerin) und der Jahres-Export (Abschnitt 7) erlauben das Aufbrechen dieser Frage auf Einzelspieler- bzw. Jahresebene. Der Permutationstest (Abschnitt 8) prüft für die sauberste Vergleichszelle — gleich starke Gegner —, ob ein Punktequote-Unterschied zwischen Frauen- und Männer-Gegnern über Stichprobenrauschen hinausgeht.
#
# **Caveats (wie Notebook 16):**
# - Bucket-Grenzen: `gleich` schließt exakt ±50 Elo ein; `schwächer`/`stärker` beginnen erst echt darüber/darunter; `Gesamt` ist die reine Summe der drei (keine eigene Stärke-Definition).
# - `own_rating` = `std_rating` zum Partie-Zeitpunkt — ein anderes Rating-Konzept als die `published_rating`-Jahresendwerte, die Kohorte und Schwellenjahr definieren; beide Konzepte sind bewusst getrennt gehalten.
# - Das Schwellenjahr-Fenster ist pro Spielerin unterschiedlich lang — Aggregat-Tabellen über alle Spielerinnen sind entsprechend nicht gleichgewichtig über die Karrierephasen verteilt.
# - Die Top-20-Kohorte ist eine echte Teilmenge der Top-40-Kohorte aus Notebook 16 (jede Top-20-Spielerin war in mindestens einem Jahr auch Top-40) — entsprechend kleinere Fallzahlen pro Zelle, siehe Abschnitt 1.
